# %%
# pgd-cifar10: normalize CWD to project root
import os
import pathlib

while (
    not pathlib.Path("pyproject.toml").exists() and pathlib.Path.cwd() != pathlib.Path.cwd().parent
):
    os.chdir("..")

# %%
# !pytest tests/test_attacks/ -q

# %% [markdown]
# # NB11 Discussion And Limitations
#
# Package the explicit limitations list and report assets for the project’s final discussion section. This notebook is where scope boundaries are surfaced directly, including the single-seed workflow and the absence of broader defense families.

# %% [markdown]
# ## Methodology
#
# Inputs: previously generated tables and figures under `results/`. Output: a curated limitations list plus a report-asset zip file. Discussion protocol: enumerate at least eight concrete limitations, including single-seed adversarial training, no AutoAttack baseline, Linf-only attacks, and other scope constraints from the implementation plan.

# %% [markdown]
# ## Execution
#
# The helper below writes `limitations.json` and bundles the tables/figures into the report-asset archive consumed by downstream reporting workflows.

# %%
from src.reporting.discussion import nb11_discussion

path = nb11_discussion()
assert path.exists()
path

# %% [markdown]
# ## Limitations
#
# NB11 documents project limitations, but it does not resolve them. In particular, any claim that depends on multi-seed adversarial training, broader threat models, or non-Linf attack families remains outside the evidentiary scope of this repo.
