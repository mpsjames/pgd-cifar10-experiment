# %%
# pgd-cifar10: normalize CWD to project root
import os
import pathlib

while (
    not pathlib.Path("pyproject.toml").exists() and pathlib.Path.cwd() != pathlib.Path.cwd().parent
):
    os.chdir("..")

# %%
# !pytest tests/test_attacks/ -q

# %% [markdown]
# # NB07a Adversarial Training ResNet-18
#
# Summarize the single-seed adversarial-training outcome for ResNet-18 and record the disclosure required by the project plan. This notebook writes the per-architecture AT table artifact without inventing missing checkpoints.

# %% [markdown]
# ## Methodology
#
# Dataset: CIFAR-10 test set, 10000 samples for clean and robust-accuracy evaluation when the adversarially trained checkpoint exists. Architecture: ResNet-18. Attack config for evaluation: PGD-10 with `epsilon=8/255`. Seed policy: adversarial training is single-seed only, `{42}`, and must be disclosed as such.

# %% [markdown]
# ## Execution
#
# The code cell below delegates to the shared notebook helper, which checks the AT checkpoint, computes clean and robust accuracy when available, and writes the result table under `results/tables/`.

# %%
from src.reporting.adversarial_training import nb07_adversarial_training

path = nb07_adversarial_training("resnet18")
assert path.exists()
path

# %% [markdown]
# ## Limitations
#
# The reported adversarial-training result is `n=1` by design and should not be interpreted as a seed-stable estimate. Any clean-versus-robust trade-off claim here is descriptive for the single run, not a multi-seed statistical conclusion.
