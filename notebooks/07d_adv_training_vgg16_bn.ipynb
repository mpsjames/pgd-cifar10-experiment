# %%
# !pytest tests/test_attacks/ -q

# %% [markdown]
# # NB07d Adversarial Training VGG-16-BN
#
# Summarize the single-seed adversarial-training outcome for VGG-16-BN and preserve the explicit disclosure that the AT phase is not reported as a multi-seed estimate.

# %% [markdown]
# ## Methodology
#
# Dataset: CIFAR-10 test set, 10000 samples when the checkpoint exists. Architecture: VGG-16-BN. Evaluation attack: PGD-10 at `epsilon=8/255`. Seed policy: single-seed adversarial training with `{42}` only. Outputs are written as per-architecture summary rows, not as a cross-seed aggregate.

# %% [markdown]
# ## Execution
#
# The helper below inspects the VGG-16-BN adversarial-training checkpoint and writes the corresponding summary table artifact under `results/tables/`.

# %%
from src.experiments.notebook_reports import nb07_adversarial_training

path = nb07_adversarial_training("vgg16_bn")
assert path.exists()
path

# %% [markdown]
# ## Limitations
#
# This notebook records only the available single-seed artifact state. It cannot support claims about variance across seeds or hyperparameter sensitivity for adversarially trained VGG-16-BN models.
