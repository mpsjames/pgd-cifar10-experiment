# %%
# pgd-cifar10: normalize CWD to project root
import os
import pathlib

while not pathlib.Path("checkpoints").exists() and pathlib.Path.cwd() != pathlib.Path.cwd().parent:
    os.chdir("..")

# %%
# !pytest tests/test_attacks/ -q

# %% [markdown]
# # NB04 Main Quantitative Results
#
# Aggregate the primary white-box attack results across architectures and attack strengths. This notebook writes the summary table and creates the main figure scaffold.

# %% [markdown]
# ## Methodology
#
# Dataset: CIFAR-10 test set, 10000 samples. Architectures: both clean models. Attack configs: FGSM, BIM-10, PGD-10, PGD-40, PGD-100, APGD-CE-10, and APGD-CE-100. Seed: `42` (single-seed experiment).

# %% [markdown]
# ## Execution
#
# The shared helper below performs checkpoint discovery and figure generation. If the full campaign has not been run yet, the notebook writes pending markers instead of synthetic metrics.

# %%
from src.reporting.main_results import nb04_main_results

table, figure = nb04_main_results()
assert table.exists() and figure.exists()
table, figure

# %% [markdown]
# ## Limitations
#
# NB04 summarizes attack outcomes for the currently available checkpoints only. Missing checkpoints remain pending, and the notebook does not by itself establish why one attack is stronger than another beyond the reported aggregate statistics.
