# %%
# pgd-cifar10: normalize CWD to project root
import os
import pathlib

while not pathlib.Path("checkpoints").exists() and pathlib.Path.cwd() != pathlib.Path.cwd().parent:
    os.chdir("..")

# %%
# !pytest tests/test_attacks/ -q

# %% [markdown]
# # NB07c Adversarial Training ViT-Tiny
#
# Summarize the single-seed adversarial-training outcome for ViT-Tiny and record the disclosure required by the project plan. The notebook writes only the artifact-backed table entry and keeps missing checkpoints explicit.

# %% [markdown]
# ## Methodology
#
# Dataset: CIFAR-10 test set, 10000 samples when the checkpoint exists. Architecture: ViT-Tiny. Evaluation attack: PGD-10 at `epsilon=8/255`. Seed policy: single-seed adversarial training with `{42}` only. Report interpretation must keep that `n=1` constraint visible.

# %% [markdown]
# ## Execution
#
# The helper below checks for the ViT-Tiny adversarial-training checkpoint, computes clean and robust accuracy when available, and writes the summary table row.

# %%
from src.reporting.adversarial_training import nb07_adversarial_training

path = nb07_adversarial_training("vit_tiny")
assert path.exists()
path

# %% [markdown]
# ## Limitations
#
# As with the other NB07 notebooks, this result is single-seed only. It is useful for documenting the achieved checkpoint state, but it is not a substitute for a multi-seed adversarial-training stability study.
