# %%
# pgd-cifar10: normalize CWD to project root
import os
import pathlib

while (
    not pathlib.Path("pyproject.toml").exists() and pathlib.Path.cwd() != pathlib.Path.cwd().parent
):
    os.chdir("..")

# %%
# !pytest tests/test_attacks/ -q

# %% [markdown]
# # NB10 Architecture Robustness Comparison
#
# Test the project’s pairwise architecture comparison claim by contrasting ResNet-18 with ViT-Tiny under a shared PGD-10 evaluation path. This notebook writes the JSON payload used to support the reframed RQ6 analysis.

# %% [markdown]
# ## Methodology
#
# Dataset: CIFAR-10 test set, 10000 samples when clean checkpoints are present. Architectures: ResNet-18 and ViT-Tiny. Attack config: PGD-10 with `epsilon=8/255`. Seed: `42` (single-seed experiment). Results are compared directly between architectures at the same seed.

# %% [markdown]
# ## Execution
#
# The helper below performs the pairwise data collection and writes the architecture-comparison JSON artifact under `results/tables/`.

# %%
from src.reporting.arch_comparison import nb10_architecture_comparison

path = nb10_architecture_comparison()
assert path.exists()
path

# %% [markdown]
# ## Limitations
#
# NB10 is intentionally a pairwise comparison, not a full ordering across all architectures. It also depends on the available clean checkpoints and should not be over-read as a comprehensive study of capacity-versus-robustness trade-offs.
