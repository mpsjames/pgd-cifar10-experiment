# %%
# !pytest tests/test_attacks/ -q

# %% [markdown]
# # NB09 Transfer Attack Analysis
#
# Analyze how PGD-crafted adversarial examples transfer across architectures and across seeds. This notebook reads transfer-run outputs from MLflow and writes the transfer-analysis table used by the report.

# %% [markdown]
# ## Methodology
#
# Dataset: CIFAR-10 test set when the transfer scripts have been run. Attack config: PGD-10 crafted on the surrogate model. Modes: `cross_arch` and `cross_seed`. Seed disclosure: cross-seed analysis exists to separate architecture effects from stochastic training-run variation.

# %% [markdown]
# ## Execution
#
# The helper below reads transfer-phase MLflow runs from the local file backend and writes a normalized CSV summary. If no transfer runs exist yet, the notebook writes pending rows instead of placeholders with invented metrics.

# %%
from src.experiments.notebook_reports import nb09_transfer_analysis

path = nb09_transfer_analysis()
assert path.exists()
path

# %% [markdown]
# ## Limitations
#
# NB09 depends on the transfer scripts having been executed beforehand, so notebook completeness is only as good as the logged MLflow runs. The table also summarizes reported transfer metrics; it does not by itself explain which architectural features drove the transfer gap.
