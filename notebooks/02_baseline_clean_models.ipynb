# %%
# pgd-cifar10: normalize CWD to project root
import os
import pathlib

while (
    not pathlib.Path("pyproject.toml").exists() and pathlib.Path.cwd() != pathlib.Path.cwd().parent
):
    os.chdir("..")

# %%
# !pytest tests/test_attacks/ -q

# %% [markdown]
# # NB02 Baseline Clean Models
#
# Summarize baseline clean accuracy across the two CIFAR-10 architectures used in this project. The notebook writes the canonical clean-accuracy table and marks missing checkpoints as `full-campaign-pending` instead of fabricating results.

# %% [markdown]
# ## Methodology
#
# Dataset: CIFAR-10 test set, 10000 samples. Architectures: `resnet18` and `vit_tiny`. Seed: `42`. Evaluation protocol: load the available clean checkpoint under `checkpoints/clean`, compute clean accuracy for the single seed, and report the result; mark the row as pending if the checkpoint does not exist yet.

# %%
from src.reporting.clean_models import nb02_clean_models

path = nb02_clean_models()
assert path.exists()
path

# %% [markdown]
# ## Limitations
#
# These numbers only describe clean accuracy. They do not say anything about adversarial robustness, transfer behavior, calibration, or whether the model later satisfies the white-box and defense claims reported in NB03-NB10.
